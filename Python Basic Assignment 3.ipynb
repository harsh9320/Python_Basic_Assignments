# %% [raw]
# 1. Why are functions advantageous to have in your programs?
# >> Functions are used so that there is no need of writing the same code again and again, we cam just simply call the fuction at any point of time required.
#
#
#
#
#
# 2. When does the code in a function run: when it's specified or when it's called?
# >> The code runs when the code is called.
#
#
#
#
#
# 3. What statement creates a function?
# >> def statement creates  a  function
#
#
#
#
# 4. What is the difference between a function and a function call?
# >> We use a def statement with number of parameters in the parenthesis to create a fucntion
# for ex :
# def test(a,b):
#  we call a fucntion by its name and desired value in parameters in parenthesis
#  for ex:
#  test(1,2)
#
#
#
#
#
# 5. How many global scopes are there in a Python program? How many local scopes?
# >> one global scopes and numerous local scopes.
#
#
#
#
#
# 6. What happens to variables in a local scope when the function call returns?
# >> the variable is destroyed.
#
#
#
#
#
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
# >> A return statement is used to end the execution of the function call and returns the results. The statements after the return statements are not executed. If the return statement is without any expression, then the special value None is returned.
#
#
#
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
# >>  none value is returned
#
#
#
#
#
#
# 9. How do you make a function variable refer to the global variable?
# >> If you want to refer to a global variable in a function, you can use the global keyword to declare which variables are global.
#
#
#
#
#
# 10. What is the data type of None?
# >> there is no data type of none.
#
#
#
#
#
# 11. What does the sentence import areallyourpetsnamederic do?
# >> It imports the module areallyourpetsnamederic.
#
#
#
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
# >> spam.bacon()
#
#
#
#
#
# 13. What can you do to save a programme from crashing if it encounters an error?
# >> we can do exception handling or try and except blocks can be introduced.
#
#
#
#
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
# >> The code in the try block is executed and if it has any errors the except block is executed.
